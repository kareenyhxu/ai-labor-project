# %% [markdown]
# ## Recover Expertise (2025)

# %% [markdown]
# ### Step 0: Necessary Packages

# %% [markdown]
# from scipy.integrate import quad
#
# quad -> a numerical integration function from SciPy. It computes definite integrals like $\int_b^a f(x) dx$.
#
# from scipy.optimize import root
#
# root -> a nonlinear equation solver. It finds values of unknown variables that make a system of equations equal zero.

# %% [markdown]
# # Navigate to the Target Folder
#
# Use terminal commands to navigate to the desired folder where the notebook will be created.

# %% [markdown]
# # Create a New Jupyter Notebook
#
# Run the jupyter notebook command to start the server and create a new notebook file in the current folder.

# %% [markdown]
# # Verify the Notebook Creation
#
# Check the folder contents to confirm the .ipynb file has been created successfully.
